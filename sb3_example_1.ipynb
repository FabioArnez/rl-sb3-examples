# %% [markdown]
# # Example 1

# %%
import gymnasium as gym
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Create environment
env = gym.make("LunarLander-v3", render_mode="rgb_array")

# %%
# Instantiate the agent
model = DQN("MlpPolicy", env, verbose=1, device='mps')
# Train the agent and display a progress bar
model.learn(total_timesteps=int(2e5), progress_bar=True)
# Save the agent
model.save("dqn_lunar")
del model  # delete trained model to demonstrate loading
# Out:
# Using mps device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /opt/miniconda3/envs/robot/lib/python3.12/site-packages/rich/live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 78       |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 561      |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 312      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.87     |
# |    n_updates        | 52       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.9     |
# |    ep_rew_mean      | -204     |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 737      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 799      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.17     |
# |    n_updates        | 174      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.8     |
# |    ep_rew_mean      | -186     |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 785      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1173     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.72     |
# |    n_updates        | 268      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.2     |
# |    ep_rew_mean      | -184     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 809      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1539     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.99     |
# |    n_updates        | 359      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 828      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2033     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.62     |
# |    n_updates        | 483      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 837      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 2502     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.68     |
# |    n_updates        | 600      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 841      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2913     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.3      |
# |    n_updates        | 703      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | -199     |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 842      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3270     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.89     |
# |    n_updates        | 792      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | -210     |
# |    exploration_rate | 0.825    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 844      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3694     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.11     |
# |    n_updates        | 898      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | -202     |
# |    exploration_rate | 0.801    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 841      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4198     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.99     |
# |    n_updates        | 1024     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | -195     |
# |    exploration_rate | 0.782    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 842      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4598     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.81     |
# |    n_updates        | 1124     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | -196     |
# |    exploration_rate | 0.755    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 839      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5168     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.78     |
# |    n_updates        | 1266     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | -202     |
# |    exploration_rate | 0.732    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 837      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5643     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.28     |
# |    n_updates        | 1385     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | -194     |
# |    exploration_rate | 0.711    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 829      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6078     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.93     |
# |    n_updates        | 1494     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 108      |
# |    ep_rew_mean      | -190     |
# |    exploration_rate | 0.691    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 825      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6502     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.25     |
# |    n_updates        | 1600     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | -189     |
# |    exploration_rate | 0.667    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 821      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7008     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.68     |
# |    n_updates        | 1726     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 110      |
# |    ep_rew_mean      | -193     |
# |    exploration_rate | 0.644    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 819      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 7502     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.439    |
# |    n_updates        | 1850     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.614    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 812      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 8128     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.601    |
# |    n_updates        | 2006     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 114      |
# |    ep_rew_mean      | -192     |
# |    exploration_rate | 0.587    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 805      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 8697     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.33     |
# |    n_updates        | 2149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | -188     |
# |    exploration_rate | 0.562    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 801      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 9231     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.19     |
# |    n_updates        | 2282     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.531    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 794      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 9872     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.09     |
# |    n_updates        | 2442     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.456    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 742      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 11452    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.36     |
# |    n_updates        | 2837     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | -180     |
# |    exploration_rate | 0.416    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 737      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 12295    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.01     |
# |    n_updates        | 3048     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 145      |
# |    ep_rew_mean      | -179     |
# |    exploration_rate | 0.338    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 708      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 13938    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.71     |
# |    n_updates        | 3459     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 156      |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.257    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 681      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 15638    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.54     |
# |    n_updates        | 3884     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | -176     |
# |    exploration_rate | 0.141    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 645      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 18078    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.28     |
# |    n_updates        | 4494     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | -175     |
# |    exploration_rate | 0.0518   |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 620      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 19963    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.08     |
# |    n_updates        | 4965     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -182     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 615      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 21163    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.921    |
# |    n_updates        | 5265     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | -187     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 614      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 21725    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.52     |
# |    n_updates        | 5406     |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       2 model = DQN("MlpPolicy", env, verbose=1, device='mps')
#       3 # Train the agent and display a progress bar
# ----> 4 model.learn(total_timesteps=int(2e5), progress_bar=True)
#       5 # Save the agent
#       6 model.save("dqn_lunar")
#
# File /opt/miniconda3/envs/robot/lib/python3.12/site-packages/stable_baselines3/dqn/dqn.py:267, in DQN.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     258 def learn(
#     259     self: SelfDQN,
#     260     total_timesteps: int,
#    (...)
#     265     progress_bar: bool = False,
#     266 ) -> SelfDQN:
# --> 267     return super().learn(
#     268         total_timesteps=total_timesteps,
#     269         callback=callback,
#     270         log_interval=log_interval,
#     271         tb_log_name=tb_log_name,
#     272         reset_num_timesteps=reset_num_timesteps,
#     273         progress_bar=progress_bar,
#     274     )
#
# File /opt/miniconda3/envs/robot/lib/python3.12/site-packages/stable_baselines3/common/off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File /opt/miniconda3/envs/robot/lib/python3.12/site-packages/stable_baselines3/dqn/dqn.py:217, in DQN.train(self, gradient_steps, batch_size)
#     215 # Optimize the policy
#     216 self.policy.optimizer.zero_grad()
# --> 217 loss.backward()
#     218 # Clip gradient norm
#     219 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# File /opt/miniconda3/envs/robot/lib/python3.12/site-packages/torch/_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File /opt/miniconda3/envs/robot/lib/python3.12/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File /opt/miniconda3/envs/robot/lib/python3.12/site-packages/torch/autograd/graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
# Load the trained agent
# NOTE: if you have loading issue, you can pass `print_system_info=True`
# to compare the system on which the model was trained vs the current one
# model = DQN.load("dqn_lunar", env=env, print_system_info=True)
model = DQN.load("dqn_lunar", env=env)

# Evaluate the agent
# NOTE: If you use wrappers with your environment that modify rewards,
#       this will be reflected here. To evaluate with original rewards,
#       wrap environment in a "Monitor" wrapper before other wrappers.
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)

# Enjoy trained agent
vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
